# %% [raw]
# Discuss string slicing and provide examples?
# String is a sequence of characters,represents and manipulates textual data
# => Srings are immutable
# Example 1:
# a="Teja"
# print(a[0:2])#obtain a part of the sting means extracting a part of the string
# output:Te#based on index value is extract characters
# Example 2:
# text = "Python Programming"
# print(text[:6])  # Output: Python
# print(text[7:])  # Output: Programming

# %% [raw]
# Explain the key features of lists in python
#
#
# 1. Ordered and Indexed
# Lists in Python maintain the order of elements. Each item in a list is assigned an index, starting from 0 for the first element.
# Example:
# my_list = [10, 20, 30]
# print(my_list[1])  # Output: 20
#
#
# 2. Mutable
# Lists are mutable, meaning you can change, add, or remove elements after the list is created. This is a key distinction from tuples, which are immutable.
# Example:
# my_list = [10, 20, 30]
# my_list[1] = 25  # Modifying the second element
# print(my_list)  # Output: [10, 25, 30]
#
#
# 3. Can Contain Heterogeneous Elements
# A single list can hold elements of different data types (integers, strings, floats, etc.).
# Example:
# mixed_list = [1, "Hello", 3.14]
# print(mixed_list)  # Output: [1, 'Hello', 3.14]
#
#
# 4. Dynamic Size
# Lists can grow and shrink dynamically, as you can add or remove elements without having to declare the size of the list upfront.
# Example:
# my_list = [1, 2, 3]
# my_list.append(4)  # Adding an element
# my_list.remove(2)  # Removing an element
# print(my_list)  # Output: [1, 3, 4]
#
#
# 5. Supports List Slicing
# Lists can be sliced to access a subset of elements. This feature works similar to string slicing.
# Example:
# my_list = [10, 20, 30, 40, 50]
# print(my_list[1:4])  # Output: [20, 30, 40]
#
#
# 6. Nested Lists (Lists within Lists)
# Lists can contain other lists, allowing for the creation of multidimensional data structures (e.g., matrices or grids).
# Example:
# nested_list = [[1, 2, 3], [4, 5, 6]]
# print(nested_list[1][2])  # Output: 6
#
#
# 7. Built-in Functions and Methods
# Python provides numerous built-in functions and methods to work with lists:
# append(): Adds an element to the end of the list.
# extend(): Appends elements from another list to the current list.
# insert(): Inserts an element at a specific position.
# remove(): Removes the first occurrence of a specified value.
# pop(): Removes an element at a given index (or the last element by default).
# sort(): Sorts the list in place.
# reverse(): Reverses the list in place.
# Example:
# my_list = [3, 1, 2]
# my_list.sort()
# print(my_list)  # Output: [1, 2, 3]
#
#
# 8. Supports Iteration
# You can easily loop over the elements of a list using a for loop.
# Example:
# my_list = [10, 20, 30]
# for item in my_list:
#     print(item)
#
# 9. Comprehensions
# Python supports list comprehensions, a concise way to create lists based on existing lists.
# Example:
# squares = [x**2 for x in range(5)]
# print(squares)  # Output: [0, 1, 4, 9, 16]
#
#
# 10. Supports Various Operations
# Lists support several operations, including concatenation, repetition, and membership testing (in).
# Example:
# list1 = [1, 2]
# list2 = [3, 4]
# combined = list1 + list2  # Concatenation
# repeated = list1 * 3  # Repetition
# print(combined)  # Output: [1, 2, 3, 4]
# print(repeated)  # Output: [1, 2, 1, 2, 1, 2]
#
# Summary of Key Features:
#
# Ordered: Lists preserve the order of elements.
# Mutable: Lists can be changed after creation.
# Heterogeneous elements: Lists can store multiple data types.
# Supports slicing and nesting: You can extract parts of a list and nest lists inside each other.
# Comprehensive methods and operations: Python provides a variety of built-in functions and methods to manipulate lists.
# Lists in Python are highly versatile and one of the most used data structures due to their flexibility in handling different data types, dynamic size, and rich set of functionalities.

# %% [raw]
# Discuss how to access, modify, delete elements in a list with examples
#
# 1. Accessing Elements in a List
# You can access elements from a list using their index, which starts from 0 for the first element.
#
# =>Accessing a Single Element
# Use the index to retrieve the value at that position.
#
# my_list = [10, 20, 30, 40, 50]
# print(my_list[2])  # Output: 30
#
# =>Accessing Multiple Elements (Slicing)
# You can use slicing to access a range of elements.
#
# my_list = [10, 20, 30, 40, 50]
# print(my_list[1:4])  # Output: [20, 30, 40]
# The slice my_list[1:4] returns the elements from index 1 to 3 (4 is excluded).
# =>Negative Indexing
# You can use negative indices to access elements from the end of the list.
#
# my_list = [10, 20, 30, 40, 50]
# print(my_list[-1])  # Output: 50
# 2. Modifying Elements in a List
# Since lists are mutable, you can modify the elements directly by assigning new values to specific indices or slices.
#
# ~Modifying a Single Element and  replace a single element using its index.
#
# my_list = [10, 20, 30, 40, 50]
# my_list[2] = 35
# print(my_list)  # Output: [10, 20, 35, 40, 50
#
# ~Modifying Multiple Elements (Slicing)
# You can modify a slice of the list by assigning new values to it.
#
# my_list = [10, 20, 30, 40, 50]
# my_list[1:4] = [25, 35, 45]
# print(my_list)  # Output: [10, 25, 35, 45, 50]
# This replaces the values at index 1, 2, and 3.
# ~Appending Elements
# To add elements to the end of the list, use the append() method.
#
# my_list = [10, 20, 30]
# my_list.append(40)
# print(my_list)  # Output: [10, 20, 30, 40]
# ~Inserting Elements
# You can insert an element at a specific position using insert().
#
# my_list = [10, 20, 30]
# my_list.insert(1, 15)
# print(my_list)  # Output: [10, 15, 20, 30]
# ~Extending a List
# You can combine two lists using extend() to add all the elements of one list to another.
#
# my_list = [10, 20]
# my_list.extend([30, 40])
# print(my_list)  # Output: [10, 20, 30, 40]
#
#
# 3. Deleting Elements from a List
# There are several ways to remove elements from a list: using the del statement, pop() method, or remove() method.
#
# Using del to Remove by Index
# You can delete an element by its index using the del keyword.
#
# my_list = [10, 20, 30, 40]
# del my_list[2]
# print(my_list)  # Output: [10, 20, 40]
# ~Using pop() to Remove and Return an Element
# The pop() method removes an element by index and returns it. If no index is specified, it removes the last element.
# my_list = [10, 20, 30, 40]
# removed_element = my_list.pop(1)
# print(my_list)  # Output: [10, 30, 40]
# print(removed_element)  # Output: 20
# ~Using remove() to Remove by Value
# The remove() method removes the first occurrence of a value from the list.
#
# my_list = [10, 20, 30, 20]
# my_list.remove(20)
# print(my_list)  # Output: [10, 30, 20]
# Only the first occurrence of 20 is removed.
# ~Clearing All Elements
# You can use the clear() method to remove all elements from the list.
#
# my_list = [10, 20, 30]
# my_list.clear()
# print(my_list)  # Output: []
# Summary
# Access: You can access elements by index, slicing, and using negative indices.
# Modify: You can modify elements by assigning new values, appending, inserting, and extending lists.
# Delete: You can remove elements using del, pop(), remove(), or clear the entire list with clear().
# These methods make Python lists a flexible and powerful data structure for various applications.

# %% [raw]
# Compare and contrast tuples and lists with examples
#
# 1. Mutability:
# Lists: Mutable — You can modify a list after its creation by adding, removing, or changing elements.
# Tuples: Immutable — Once a tuple is created, you cannot change its elements (no addition, deletion, or modification).
# Example:
#
# # List example (Mutable)
# my_list = [1, 2, 3]
# my_list[1] = 10  # Modifying the second element
# print(my_list)   # Output: [1, 10, 3]
#
# # Tuple example (Immutable)
# my_tuple = (1, 2, 3)
# # my_tuple[1] = 10  # This will raise a TypeError since tuples can't be modified
# 2. Syntax:
# Lists: Created using square brackets [].
# Tuples: Created using parentheses ().
# Example:
#
# # List
# my_list = [1, 2, 3]
#
# # Tuple
# my_tuple = (1, 2, 3)
# 3. Performance:
# Lists: Slightly slower compared to tuples when it comes to iteration and access, as lists allow changes and Python needs to manage the flexibility.
# Tuples: Faster because they are immutable and have less overhead.
#
#
# 4. Methods:
# Lists: Have many methods like append(), remove(), pop(), and sort() for modifying the content.
# Tuples: Limited to methods like count() and index() since they can't be modified.
# Example:
#
# # List methods
# my_list = [1, 2, 3]
# my_list.append(4)  # Adds 4 to the list
# print(my_list)     # Output: [1, 2, 3, 4]
#
# # Tuple methods
# my_tuple = (1, 2, 3)
# print(my_tuple.count(2))  # Output: 1 (Counts the number of occurrences of 2)

# %% [raw]
# Describe the key features of sets and provide examples of their use
# 1)Set Comprehensions: Similar to list comprehensions, Python allows for set comprehensions, which can be used to generate sets based on existing iterables.
#
# Example:
# my_set = {x * 2 for x in range(5)}
# print(my_set)  # Output: {0, 2, 4, 6, 8}
# 2)Frozen Sets: Immutable version of sets. Once created, you cannot add or remove elements from a frozen set.
#
# Example:
#
# my_frozenset = frozenset([1, 2, 3])
# # my_frozenset.add(4)  # This will raise an AttributeError
# print(my_frozenset)  # Output: frozenset({1, 2, 3})
# 3)Unordered:
#
# Sets do not maintain any specific order. When you display a set, the elements may appear in any order, and this order can change over time.
# Example:
# my_set = {1, 2, 3, 4}
# print(my_set)  # Output may not be in the order of insertion
# 4)Unique Elements:
#
# A set automatically removes duplicates. Each element in a set must be unique.
# Example:
#
# my_set = {1, 2, 2, 3}
# print(my_set)  # Output: {1, 2, 3}
# 5)Mutable:
#
# Sets are mutable, meaning you can add or remove elements after the set has been created.
# Example:
# my_set = {1, 2, 3}
# my_set.add(4)  # Adding an element
# my_set.remove(2)  # Removing an element
# print(my_set)  # Output: {1, 3, 4}
# 6)No Indexing:
#
# Since sets are unordered, you cannot access elements via an index, unlike lists or tuples.
# Example:
# my_set = {1, 2, 3}
# # my_set[0]  # This will raise a TypeError since sets do not support indexing
# 7)Membership:
#
# my_set = {1, 2, 3}
# print(2 in my_set)  # Output: True
# 8)Mathematical Set Operations:
#
# Sets support operations like union, intersection, difference, and symmetric difference, which are useful for comparing and combining datasets.
# Examples:
#
# Union (| or union()): Combines two sets, including all elements from both.
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# print(set1 | set2)  # Output: {1, 2, 3, 4, 5}
# ~Intersection (& or intersection()): Returns elements that are present in both sets.
#
# print(set1 & set2)  # Output: {3}
# ~Difference (- or difference()): Returns elements in the first set but not in the second.
#
# print(set1 - set2)  # Output: {1, 2}
# ~Symmetric Difference (^ or symmetric_difference()): Returns elements in either of the sets but not in both.
#
# print(set1 ^ set2)  # Output: {1, 2, 4, 5}

# %% [raw]
# Discuss the use cases of tuples and sets in Python programming
# Tuples are extremely useful in situations where immutability, memory efficiency, and data integrity are critical. They are used for returning multiple values from functions, storing fixed data, creating dictionary keys, ensuring data remains unmodified, and working efficiently with large amounts of data in algorithms. Their role in creating lightweight, structured data containers makes them an essential part of Python programming.
#
# Sets in Python are highly optimized for storing unique elements, performing membership tests, and executing operations like union, intersection, and difference. Here are some common use cases of sets in Python programming
# Sets are highly useful for eliminating duplicates, membership testing, and performing set-based operations like union, intersection, and difference. They are also optimized for fast lookups, making them suitable for large datasets where frequent checks for the presence of elements are required.
# Their key features make them ideal for use cases like cleaning data, comparing datasets, filtering, and ensuring data uniqueness in applications like web scraping, data processing, and algorithms.

# %% [raw]
# Describe how to add, modify, and delete items in a dictionary with examples
# 1. Adding an Item to a Dictionary:
# To add a new key-value pair to a dictionary, you simply assign a value to a new key. If the key already exists, the value will be updated.
#
# Example:
#
# student = {"name": "Alice", "age": 20}
#
# # Adding a new key-value pair for 'major'
# student["major"] = "Computer Science"
# print(student)  # Output: {'name': 'Alice', 'age': 20, 'major': 'Computer Science'}
# 2. Modifying an Item in a Dictionary:
# You can modify the value of an existing key by assigning a new value to it.
#
# Example:
#
# student = {"name": "Alice", "age": 20}
#
# # Modifying the value of the 'age' key
# student["age"] = 21
# print(student)  # Output: {'name': 'Alice', 'age': 21}
# 3. Deleting an Item from a Dictionary:
# To delete a key-value pair, you can use the del statement, or the pop() method, which also returns the value being removed.
#
# Example using del:
#
# student = {"name": "Alice", "age": 21, "major": "Computer Science"}
#
# # Deleting the 'major' key
# del student["major"]
# print(student)  # Output: {'name': 'Alice', 'age': 21}
# ~Example using pop():
#
# student = {"name": "Alice", "age": 21, "major": "Computer Science"}
#
# # Deleting the 'major' key and getting its value
# removed_value = student.pop("major")
# print(student)  # Output: {'name': 'Alice', 'age': 21}
# print(removed_value)  # Output: Computer Science

# %% [raw]
# Discuss the importance of dictionary keys being immutable and provide examples.
# 1. Hashing and Performance:
# Dictionaries in Python are implemented using hash tables, which rely on the fact that keys have a fixed, unique hash value to store and retrieve data efficiently. Immutable keys (like strings, numbers, and tuples) ensure that the hash value remains constant.
# If keys were mutable, their hash value could change, making it impossible to reliably locate the corresponding value in the dictionary, thus breaking the dictionary’s fast lookup capability.
# 2. Data Integrity and Consistency:
# Immutability ensures that dictionary keys are stable and consistent throughout the program's execution. If keys were mutable, any modification to a key could lead to unpredictable behavior and make it difficult to maintain data integrity. Changing a key’s value after insertion would essentially make it impossible to retrieve the associated value.
#  code
# Example 1: Using an Immutable Key (String):
# In this example, we use a string (an immutable type) as a key.
#
# employee = {
#     "name": "Alice",
#     "age": 30,
#     "department": "HR"
# }
#
# # Accessing the value using the immutable key 'name'
# print(employee["name"])  # Output: Alice
# Explanation:
#
# The key "name" is a string, which is immutable. Once added to the dictionary, it cannot be changed, ensuring that the key consistently maps to the value "Alice".
# Example 2: Attempting to Use a Mutable Key (List):
# Lists are mutable, so trying to use a list as a dictionary key will result in an error.
#
# # Attempting to use a mutable list as a key will raise an error
# invalid_dict = {
#     [1, 2, 3]: "invalid key"
# }
